# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ../lib/kaggle/gcp.py
# ../input/bitfest-datathon-2025/sample_submission.csv
# ../input/bitfest-datathon-2025/train.csv
# ../input/bitfest-datathon-2025/test.csv

# %%
# =========================================================
import pandas as pd
import numpy as np
import ast
import re
from datetime import datetime
from dateutil import parser
from collections import Counter

from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import HistGradientBoostingRegressor, GradientBoostingRegressor

from textblob import TextBlob
from fuzzywuzzy import fuzz
from sklearn.preprocessing import RobustScaler


import gc
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
train_path = '/kaggle/input/bitfest-datathon-2025/train.csv'
test_path  = '/kaggle/input/bitfest-datathon-2025/test.csv'
sample_sub_path = '/kaggle/input/bitfest-datathon-2025/sample_submission.csv'

# %%
seed=42
def parse_list( x):
    """Parse string representation of lists"""
    if pd.isnull(x):
        return []
    try:
        return ast.literal_eval(x)
    except:
        return []

def extract_skill_overlap( row):
    """Calculate skill overlap ratio"""
    candidate = set(row['skills']) if 'skills' in row else set()
    required  = set(row['skills_required']) if 'skills_required' in row else set()
    if not candidate or not required:
        return 0.0
    inter = candidate.intersection(required)
    union = candidate.union(required)
    return len(inter) / len(union) if union else 0.0

def extract_total_experience_months( row):
    """Calculate total months of experience"""
    start_str = row['start_dates']
    end_str = row['end_dates']
    start = parse_date(start_str)
    end = parse_date(end_str)
    if start is None or end is None:
        return 0
    diff = (end.year - start.year)*12 + (end.month - start.month)
    return max(diff, 0)
def parse_date( date_str):
    """Parse date string"""
    if pd.isnull(date_str):
        return None
    if any(word.lower() in str(date_str).lower() for word in ['till','present']):
        return datetime.now()
    try:
        return parser.parse(str(date_str))
    except:
        return None

def extract_passing_year( val):
    """Extract passing year as integer"""
    if pd.isnull(val):
        return 0
    try:
        yrs = ast.literal_eval(val)
        if isinstance(yrs, list) and len(yrs) > 0:
            yrs_numeric = [int(x) for x in yrs if str(x).isdigit()]
            if len(yrs_numeric) == 0:
                return 0
            return max(yrs_numeric)
    except:
        pass
    return 0


def extract_education_features( df):
    """Enhanced education feature extraction"""
    def get_education_level(degree):
        if pd.isna(degree):
            return 0
        degree = degree.lower()
        if 'phd' in degree or 'doctorate' in degree:
            return 4
        elif 'master' in degree or 'mba' in degree:
            return 3
        elif 'bachelor' in degree or 'bsc' in degree:
            return 2
        elif 'diploma' in degree or 'certificate' in degree:
            return 1
        return 0

    df['education_level'] = df['degree_names'].apply(get_education_level)

    def extract_numeric_result(x):
        if pd.isna(x):
            return 0.0
        try:
            matches = re.findall(r'\d+\.?\d*', str(x))
            if matches:
                return float(matches[0])
            return 0.0
        except:
            return 0.0

    df['numeric_result'] = df['educational_results'].apply(extract_numeric_result)

    # Education-job requirement match score using fuzzy matching
    df['education_match'] = df.apply(
        lambda x: fuzz.ratio(
            str(x['degree_names']).lower(), 
            str(x['educationaL_requirements']).lower()
        ) / 100.0, 
        axis=1
    )

    return df

def extract_experience_features( df):
    """Enhanced experience feature extraction"""
    df['required_years'] = df['experiencere_requirement'].apply(extract_years)

    # Calculate total experience in months
    df['total_experience_months'] = df.apply(
        extract_total_experience_months, axis=1
    )

    # Experience match score
    df['experience_match'] = (
        df['total_experience_months'] / df['required_years'].replace(0, 1)
    ).clip(0, 2)

    return df

def extract_years( text):
    """Extract years from text"""
    if pd.isna(text):
        return 0
    years = re.findall(r'(\d+)[\s-]*year', text.lower())
    return int(years[0]) if years else 0



def extract_text_features( df):
    """Enhanced text feature extraction"""
    # Sentiment analysis
    df['objective_sentiment'] = df['career_objective'].apply(
        lambda x: TextBlob(str(x)).sentiment.polarity
    )

    # Text length features
    df['objective_length'] = df['career_objective'].str.len()
    df['resp_length'] = df['responsibilities'].str.len()

    # Keyword matching between responsibilities
    df['resp_match'] = df.apply(
        lambda x: fuzz.ratio(
            str(x['responsibilities']), 
            str(x['responsibilities.1'])
        ) / 100.0,
        axis=1
    )

    return df




def extract_skill_features(df):
    """Enhanced skill feature extraction."""
    df['skills'] = df['skills'].apply(parse_list)
    df['skills_required'] = df['skills_required'].apply(parse_list)

    # Skill overlap
    df['skill_overlap'] = df.apply(extract_skill_overlap, axis=1)

    # Skill coverage
    df['skill_coverage'] = df.apply(
        lambda x: len(x['skills']) / max(len(x['skills_required']), 1)
        if len(x['skills_required']) > 0 else 0, axis=1
    )

    # Enhanced Skill Importance
    skill_freq = Counter()
    for skills in df['skills']:
        skill_freq.update(skills)
    
    df['skill_importance_score'] = df.apply(
        lambda x: sum(1/np.log2(skill_freq[skill] + 1) 
                      for skill in set(x['skills']).intersection(set(x['skills_required'])))
        if len(x['skills_required']) > 0 else 0,
        axis=1
    )

    # Drop original skills columns to save memory
    df.drop(['skills', 'skills_required'], axis=1, inplace=True)

    return df

def extract_position_match(row):
    """Calculate match score between 'positions' and 'job_position_name'."""
    # Safely extract the values from the row
    position = str(row.get('positions', '')).lower()
    job_position = str(row.get('﻿job_position_name', '')).lower()
    
    # Calculate the fuzzy ratio only if both fields are not empty
    if position and job_position:
        return fuzz.ratio(position, job_position) / 100.0
    else:
        return 0.0  # Return 0.0 if either field is empty
def extract_position_features(df):
    """Feature engineering for positions."""
    df['position_match'] = df.apply(extract_position_match, axis=1)
    return df


def create_interaction_features(df):
    """Create interaction features."""
    df['skill_edu_interaction'] = df['skill_overlap'] * df['education_match']
    df['skill_exp_interaction'] = df['skill_overlap'] * df['experience_match']
    df['edu_exp_interaction'] = df['education_match'] * df['experience_match']

    # New interaction features
    df['position_skill_match'] = df['position_match'] * df['skill_overlap']
    df['position_edu_interaction'] = df['position_match'] * df['education_match']

    return df


def encode_categorical_features(train_df, test_df, categorical_cols):
    """
    Encode categorical features where each cell can have multiple categories (e.g., lists) using One-Hot Encoding.
    """
    for col in categorical_cols:
        print(f"Raw data sample for column {col} in train_df:")
        print(train_df[col].head(10))
        print(f"Raw data sample for column {col} in test_df:")
        print(test_df[col].head(10))
        # print(f"Data type of column {col} in train_df: {train_df[col].dtype}")
        # print(f"Data type of column {col} in test_df: {test_df[col].dtype}")
        if col in train_df.columns:
            # Ensure cells are parsed correctly as lists and handle empty/null values
            train_df[col] = train_df[col].apply(lambda x: eval(x) if isinstance(x, str) and x.startswith('[') else x)
            test_df[col] = test_df[col].apply(lambda x: eval(x) if isinstance(x, str) and x.startswith('[') else x)

            train_df[col] = train_df[col].apply(lambda x: x if isinstance(x, list) and len(x) > 0 else ['unknown'])
            test_df[col] = test_df[col].apply(lambda x: x if isinstance(x, list) and len(x) > 0 else ['unknown'])
            
            # Combine unique categories from both train and test
            all_categories = pd.concat(
                [train_df[col].explode(), test_df[col].explode()], axis=0
            ).fillna('unknown').unique()

            #print(f"All categories for column {col}: {all_categories}")  # Debugging
            
            # Create binary columns for each category
            for category in all_categories:
                train_df[f'{col}_{category}'] = train_df[col].apply(lambda x: 1 if category in x else 0)
                test_df[f'{col}_{category}'] = test_df[col].apply(lambda x: 1 if category in x else 0)
                
    return train_df, test_df





def extract_text_features_tf_idf_svd_scaled(train_df, test_df, text_cols, max_features=500, n_components=50):
    """Encode text features using TF-IDF Vectorization, SVD, and scale the SVD features."""
    scaler = StandardScaler()  # Initialize the scaler
    svd_cols = []  # List to store names of SVD columns created

    for col in text_cols:
        print(f"Processing TF-IDF for column: {col}")
        tfidf = TfidfVectorizer(
            stop_words='english',
            max_features=max_features,
            ngram_range=(1, 2)
        )

        # Fit TF-IDF on train and transform train/test
        tfidf.fit(train_df[col].fillna('').astype(str))
        train_tfidf = tfidf.transform(train_df[col].fillna('').astype(str))
        test_tfidf = tfidf.transform(test_df[col].fillna('').astype(str))

        # Truncated SVD
        svd = TruncatedSVD(n_components=n_components, random_state=42)
        svd.fit(train_tfidf)
        train_svd = svd.transform(train_tfidf)
        test_svd = svd.transform(test_tfidf)

        # Scale the SVD components
        train_svd_scaled = scaler.fit_transform(train_svd)  # Fit and transform on training data
        test_svd_scaled = scaler.transform(test_svd)        # Transform on test data

        # Add scaled SVD components as new features
        for i in range(n_components):
            svd_col_name = f'{col}_svd_scaled_{i}'
            train_df[svd_col_name] = train_svd_scaled[:, i]
            test_df[svd_col_name] = test_svd_scaled[:, i]
            svd_cols.append(svd_col_name)  # Append to the list of SVD columns

    # Drop original text columns
    train_df.drop(text_cols, axis=1, inplace=True)
    test_df.drop(text_cols, axis=1, inplace=True)
    gc.collect()

    return train_df, test_df, svd_cols






def prepare_features(train_df, test_df):
    """Prepare features for modeling."""
    # Fill missing numeric values with 0
    numeric_cols = ['skill_overlap', 'skill_coverage', 'skill_importance_score',
                    'objective_sentiment', 'objective_length', 'resp_length',
                    'resp_match', 'skill_edu_interaction', 'skill_exp_interaction',
                    'edu_exp_interaction', 'total_experience_months', 'passing_year',
                    'position_match', 'position_skill_match', 'position_edu_interaction']

    for col in numeric_cols:
        if col in train_df.columns:
            train_df[col] = train_df[col].fillna(0)
        if col in test_df.columns:
            test_df[col] = test_df[col].fillna(0)

    return train_df, test_df

# %%
# def emphasize_numerical_features(train_df, test_df, numerical_cols, svd_cols, weight_factor=2.0):
#     """
#     Emphasize numerical features by scaling them and optionally weighting them more heavily than SVD features.
#     """
#     # Initialize scalers
#     numerical_cols = [col for col in numerical_cols if col in train_df.columns and col in test_df.columns]
#     numerical_scaler = StandardScaler()
#     svd_scaler = StandardScaler()

#     # Scale and emphasize numerical features
#     train_df[numerical_cols] = numerical_scaler.fit_transform(train_df[numerical_cols])
#     test_df[numerical_cols] = numerical_scaler.transform(test_df[numerical_cols])
    
#     train_df[numerical_cols] *= weight_factor
#     test_df[numerical_cols] *= weight_factor

#     # Scale SVD features
#     train_df[svd_cols] = svd_scaler.fit_transform(train_df[svd_cols])
#     test_df[svd_cols] = svd_scaler.transform(test_df[svd_cols])

#     # Combine emphasized numerical and scaled SVD features into separate DataFrames for clarity
#     train_combined = train_df[numerical_cols + svd_cols + ['matched_score']].copy()
#     test_combined = test_df[numerical_cols + svd_cols].copy()

#     return train_combined, test_combined


def emphasize_numerical_features(train_df, test_df, numerical_cols, svd_cols, weight_factor=2.0):
    """
    Emphasize numerical features by scaling them and optionally weighting them more heavily than SVD features.
    Includes one-hot encoded columns dynamically.
    """

    numerical_cols = [col for col in numerical_cols if col in train_df.columns and col in test_df.columns]
    # Identify all numerical columns (explicit + dynamically generated one-hot encoded columns)
    one_hot_encoded_cols = [col for col in train_df.columns if col not in numerical_cols + svd_cols + ['matched_score'] and train_df[col].dtype in [np.int64, np.float64]]
    all_numerical_cols = numerical_cols + one_hot_encoded_cols
    
    print("Final numerical columns (including one-hot encoded):", all_numerical_cols)
    
    # Initialize scalers
    numerical_scaler = StandardScaler()
    svd_scaler = StandardScaler()
    
    # Scale and emphasize numerical features
    train_df[all_numerical_cols] = numerical_scaler.fit_transform(train_df[all_numerical_cols])
    test_df[all_numerical_cols] = numerical_scaler.transform(test_df[all_numerical_cols])
    
    train_df[all_numerical_cols] *= weight_factor
    test_df[all_numerical_cols] *= weight_factor
    
    # Scale SVD features
    train_df[svd_cols] = svd_scaler.fit_transform(train_df[svd_cols])
    test_df[svd_cols] = svd_scaler.transform(test_df[svd_cols])
    
    # Combine emphasized numerical and scaled SVD features into separate DataFrames for clarity
    train_combined = train_df[all_numerical_cols + svd_cols + ['matched_score']].copy()
    test_combined = test_df[all_numerical_cols + svd_cols].copy()
    
    return train_combined, test_combined

# %%
import numpy as np
from sklearn.ensemble import HistGradientBoostingRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

def cross_validate_model(train_df, features, target, params_hgb, params_gb, test_df, n_folds=5, random_state=42):
    """
    Perform K-Fold Cross-Validation with HistGradientBoostingRegressor and GradientBoostingRegressor.
    
    Args:
    - train_df (pd.DataFrame): Training data.
    - features (list): List of feature column names.
    - target (str): Target column name.
    - params_hgb (dict): Parameters for HistGradientBoostingRegressor.
    - params_gb (dict): Parameters for GradientBoostingRegressor.
    - test_df (pd.DataFrame): Testing data (features only).
    - n_folds (int): Number of folds for cross-validation.
    - random_state (int): Random state for reproducibility.

    Returns:
    - final_test_preds (np.array): Averaged predictions for the test set.
    - avg_mse (float): Average MSE across folds for both models.
    """
    # Initialize KFold
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)

    # Initialize variables for predictions and metrics
    oof_preds_hgb = np.zeros(len(train_df))
    oof_preds_gb = np.zeros(len(train_df))
    test_preds_hgb = np.zeros(len(test_df))
    test_preds_gb = np.zeros(len(test_df))
    fold_mses_hgb = []
    fold_mses_gb = []

    # Perform K-Fold Cross-Validation
    for fold, (train_idx, val_idx) in enumerate(kf.split(train_df)):
        print(f'\nTraining fold {fold + 1} / {n_folds}')
        
        # Split data into training and validation folds
        X_train_fold = train_df.iloc[train_idx][features]
        y_train_fold = train_df.iloc[train_idx][target]
        X_val_fold = train_df.iloc[val_idx][features]
        y_val_fold = train_df.iloc[val_idx][target]
        
        # Train HistGradientBoostingRegressor
        hgb = HistGradientBoostingRegressor(**params_hgb)
        hgb.fit(X_train_fold, y_train_fold)
        y_pred_hgb = hgb.predict(X_val_fold)
        mse_hgb = mean_squared_error(y_val_fold, y_pred_hgb)
        fold_mses_hgb.append(mse_hgb)
        print(f"Fold {fold + 1} HistGradientBoostingRegressor MSE: {mse_hgb:.6f}")
        oof_preds_hgb[val_idx] = y_pred_hgb
        
        # Predict on test set
        y_test_pred_hgb = hgb.predict(test_df[features])
        test_preds_hgb += y_test_pred_hgb / n_folds
        
        # Train GradientBoostingRegressor
        gb = GradientBoostingRegressor(**params_gb)
        gb.fit(X_train_fold, y_train_fold)
        y_pred_gb = gb.predict(X_val_fold)
        mse_gb = mean_squared_error(y_val_fold, y_pred_gb)
        fold_mses_gb.append(mse_gb)
        print(f"Fold {fold + 1} GradientBoostingRegressor MSE: {mse_gb:.6f}")
        oof_preds_gb[val_idx] = y_pred_gb
        
        # Predict on test set
        y_test_pred_gb = gb.predict(test_df[features])
        test_preds_gb += y_test_pred_gb / n_folds
    
    # Calculate average MSE
    avg_mse_hgb = np.mean(fold_mses_hgb)
    avg_mse_gb = np.mean(fold_mses_gb)
    print(f"\nAverage HistGradientBoostingRegressor MSE: {avg_mse_hgb:.6f}")
    print(f"Average GradientBoostingRegressor MSE: {avg_mse_gb:.6f}")
    
    # Average predictions from both models
    final_test_preds = (test_preds_hgb + test_preds_gb) / 2
    
    return final_test_preds, (avg_mse_hgb + avg_mse_gb) / 2

# %%
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
sample_submission = pd.read_csv(sample_sub_path)

print("Initial train shape:", train_df.shape)
print("Initial test shape:", test_df.shape)
# Out:
# Initial train shape: (7635, 35)
# Initial test shape: (1909, 35)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   address                              633 non-null    object
#  1   career_objective                     3794 non-null   object
#  2   skills                               7592 non-null   object
#  3   educational_institution_name         7574 non-null   object
#  4   degree_names                         7574 non-null   object
#  5   passing_years                        7574 non-null   object
#  6   educational_results                  7574 non-null   object
#  7   result_types                         7574 non-null   object
#  8   major_field_of_studies               7574 non-null   object
#  9   professional_company_names           7568 non-null   object
#  10  company_urls                         7568 non-null   object
#  11  start_dates                          7568 non-null   object
#  12  end_dates                            7568 non-null   object
#  13  related_skils_in_job                 7568 non-null   object
#  14  positions                            7568 non-null   object
#  15  locations                            7568 non-null   object
#  16  responsibilities                     7635 non-null   object
#  17  extra_curricular_activity_types      2732 non-null   object
#  18  extra_curricular_organization_names  2732 non-null   object
#  19  extra_curricular_organization_links  2732 non-null   object
#  20  role_positions                       2732 non-null   object
#  21  languages                            569 non-null    object
#  22  proficiency_levels                   569 non-null    object
#  23  certification_providers              1587 non-null   object
#  24  certification_skills                 1587 non-null   object
#  25  online_links                         1587 non-null   object
#  26  issue_dates                          1587 non-null   object
#  27  expiry_dates                         1587 non-null   object
#  28  ﻿job_position_name                   7635 non-null   object
#  29  educationaL_requirements             7635 non-null   object
#  30  experiencere_requirement             6549 non-null   object
#  31  age_requirement                      4371 non-null   object
#  32  responsibilities.1                   7635 non-null   object
#  33  skills_required                      6264 non-null   object
#  34  matched_score                        7635 non-null   float64
# dtypes: float64(1), object(34)
# memory usage: 2.0+ MB

# %%
print(train_df['positions']+"========="+train_df['﻿job_position_name'])
# print(train_df['responsibilities'][578])

# %%
# Drop columns >80% missing
col_threshold = 0.6
cols_to_drop = [col for col in train_df.columns if train_df[col].isnull().mean() > col_threshold]
train_df.drop(cols_to_drop, axis=1, inplace=True, errors='ignore')
test_df.drop(cols_to_drop, axis=1, inplace=True, errors='ignore')
print("Dropped columns:", cols_to_drop)

# Drop rows with <5 non-null in train
row_threshold = 5
before_rows = len(train_df)
train_df.dropna(thresh=row_threshold, axis=0, inplace=True)
after_rows = len(train_df)
print(f"Dropped {before_rows - after_rows} rows with < {row_threshold} non-null columns.")

print("Train shape after drops:", train_df.shape)
print("Test shape after drops:", test_df.shape)
# Out:
# Dropped columns: ['address', 'extra_curricular_activity_types', 'extra_curricular_organization_names', 'extra_curricular_organization_links', 'role_positions', 'languages', 'proficiency_levels', 'certification_providers', 'certification_skills', 'online_links', 'issue_dates', 'expiry_dates']
# Dropped 0 rows with < 5 non-null columns.
# Train shape after drops: (7635, 23)
# Test shape after drops: (1909, 23)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   career_objective              3794 non-null   object
#  1   skills                        7592 non-null   object
#  2   educational_institution_name  7574 non-null   object
#  3   degree_names                  7574 non-null   object
#  4   passing_years                 7574 non-null   object
#  5   educational_results           7574 non-null   object
#  6   result_types                  7574 non-null   object
#  7   major_field_of_studies        7574 non-null   object
#  8   professional_company_names    7568 non-null   object
#  9   company_urls                  7568 non-null   object
#  10  start_dates                   7568 non-null   object
#  11  end_dates                     7568 non-null   object
#  12  related_skils_in_job          7568 non-null   object
#  13  positions                     7568 non-null   object
#  14  locations                     7568 non-null   object
#  15  responsibilities              7635 non-null   object
#  16  ﻿job_position_name            7635 non-null   object
#  17  educationaL_requirements      7635 non-null   object
#  18  experiencere_requirement      6549 non-null   object
#  19  age_requirement               4371 non-null   object
#  20  responsibilities.1            7635 non-null   object
#  21  skills_required               6264 non-null   object
#  22  matched_score                 7635 non-null   float64
# dtypes: float64(1), object(22)
# memory usage: 1.3+ MB

# %%
print("\nExtracting features...")
for df in [train_df, test_df]:
    df = extract_education_features(df)
    df = extract_experience_features(df)
    df = extract_skill_features(df)
    df = extract_position_features(df)
    df = extract_text_features(df)
    df = create_interaction_features(df)
# Out:
# Extracting features...

# %%
pd.set_option('display.max_rows', None)

# %%
#train_df.head()
train_df.info()
#train_df['educational_institution_name']
numerical = train_df.select_dtypes(include=['int64', 'float64','int32', 'float32'])
numerical_cols = numerical.columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   career_objective              3794 non-null   object
#  1   educational_institution_name  7574 non-null   object
#  2   degree_names                  7574 non-null   object
#  3   passing_years                 7574 non-null   object
#  4   educational_results           7574 non-null   object
#  5   result_types                  7574 non-null   object
#  6   major_field_of_studies        7574 non-null   object
#  7   professional_company_names    7568 non-null   object
#  8   company_urls                  7568 non-null   object
#  9   start_dates                   7568 non-null   object
#  10  end_dates                     7568 non-null   object
#  11  related_skils_in_job          7568 non-null   object
#  12  positions                     7568 non-null   object
#  13  locations                     7568 non-null   object
#  14  responsibilities              7635 non-null   object
#  15  ﻿job_position_name            7635 non-null   object
#  16  educationaL_requirements      7635 non-null   object
#  17  experiencere_requirement      6549 non-null   object
#  18  age_requirement               4371 non-null   object
#  19  responsibilities.1            7635 non-null   object
#  20  matched_score                 7635 non-null   float64
#  21  education_level               7635 non-null   int64
#  22  numeric_result                7635 non-null   float64
#  23  education_match               7635 non-null   float64
#  24  required_years                7635 non-null   int64
#  25  total_experience_months       7635 non-null   int64
#  26  experience_match              7635 non-null   float64
#  27  skill_overlap                 7635 non-null   float64
#  28  skill_coverage                7635 non-null   int64
#  29  skill_importance_score        7635 non-null   int64
#  30  position_match                7635 non-null   float64
#  31  objective_sentiment           7635 non-null   float64
#  32  objective_length              3794 non-null   float64
#  33  resp_length                   7635 non-null   int64
#  34  resp_match                    7635 non-null   float64
#  35  skill_edu_interaction         7635 non-null   float64
#  36  skill_exp_interaction         7635 non-null   float64
#  37  edu_exp_interaction           7635 non-null   float64
#  38  position_skill_match          7635 non-null   float64
#  39  position_edu_interaction      7635 non-null   float64
# dtypes: float64(14), int64(6), object(20)
# memory usage: 2.3+ MB

# %%
train_df['result_types'].head(10)

# %%
# Define categorical columns
# categorical_cols = [
#     'educational_institution_name',
#     'major_field_of_studies',
#     'degree_names',
#     'result_types',
#     'professional_company_names',
#     'role_positions',
#     'certification_providers',
#     'extra_curricular_organization_names'
# ]
categorical_cols = [
    'educational_institution_name',
    'major_field_of_studies',
    'degree_names',
    'result_types',
    'professional_company_names'
]
# Encode categorical features
train_df, test_df = encode_categorical_features(train_df, test_df, categorical_cols)
# Out:
# Raw data sample for column educational_institution_name in train_df:
# 0    ['The Amity School of Engineering & Technology...
# 1    ['Delhi University - Hansraj College', 'Delhi ...
# 2      ['Birla Institute of Technology (BIT), Ranchi']
# 3    ['Martinez Adult Education, Business Training ...
# 4                            ['Kent State University']
# 5    ['Glen Oaks High School', 'Glen Oaks High Scho...
# 6                       ['DJR College and University']
# 7            ['POLYTECHNIC UNIVERSITY OF PUERTO RICO']
# 8                                ['Nagpur University']
# 9    ['Dr. Virendra Swaroop Institute of Computer S...
# Name: educational_institution_name, dtype: object
# Raw data sample for column educational_institution_name in test_df:
# 0    ['The Amity School of Engineering & Technology...
# 1    ['Arizona State University', 'Arizona State Un...
# 2    ['GODAVARI INSTITUTE OF ENGINEERING AND TECHNO...
# 3    ['DVR College of Engineering & Technology', 'C...
# 4                                ['HiiT College, Goa']
# 5                         ['Arizona State University']
# 6    ['Indiana University', 'University of Evansvil...
# 7             ['Cummins College of Engineering, Pune']
# 8    ['Ball State University', 'Ball State Universi...
# 9    ['Illinois Institute of Technology', 'National...
# Name: educational_institution_name, dtype: object
# Raw data sample for column major_field_of_studies in train_df:
# 0                                      ['Electronics']
# 1                        ['Mathematics', 'Statistics']
# 2                    ['Electronics/Telecommunication']
# 3                            ['Computer Applications']
# 4                                       ['Accounting']
# 5    ['Electronics and Communications Engineering T...
# 6                                               ['IT']
# 7                           ['Electrical Engineering']
# 8                    ['Electronics/Telecommunication']
# 9                           ['Computers', 'Computers']
# Name: major_field_of_studies, dtype: object
# Raw data sample for column major_field_of_studies in test_df:
# 0                                      ['Electronics']
# 1    ['Mechanical Engineering', 'Mechanical Enginee...
# 2                                       ['Mechanical']
# 3    ['Electronics & Computers', 'Software Developm...
# 4                       ['Electrical and Electronics']
# 5                              ['Business Management']
# 6               [None, 'Electrical Engineering', None]
# 7                                              ['N/A']
# 8            ['Accounting', 'Business Administration']
# 9    ['Computer Science', 'Electronics and Communic...
# Name: major_field_of_studies, dtype: object
# Raw data sample for column degree_names in train_df:
# 0                                           ['B.Tech']
# 1      ['B.Sc (Maths)', 'M.Sc (Science) (Statistics)']
# 2                                           ['B.Tech']
# 3    ['Computer Applications Specialist Certificate...
# 4              ['Bachelor of Business Administration']
# 5              ['Bachelor Degree', 'Associate Degree']
# 6                                           ['B.Tech']
# 7                              ['Bachelor of Science']
# 8                                      ['B.Tech/B.E.']
# 9                                       ['BCA', 'MCA']
# Name: degree_names, dtype: object
# Raw data sample for column degree_names in test_df:
# 0                                           ['B.Tech']
# 1        ['Doctor of Philosophy', 'Master of Science']
# 2                              ['B.Tech (Mechanical)']
# 3                        ['B.Tech', 'Post Graduation']
# 4                                           ['B.Tech']
# 5                              ['Bachelor of Science']
# 6    ['Master of Business Administration', 'Bachelo...
# 7                                           ['B.Tech']
# 8         ['Master of Science', 'Bachelor of Science']
# 9                                       ['M.S', 'B.E']
# Name: degree_names, dtype: object
# Raw data sample for column result_types in train_df:
# 0            [None]
# 1    ['N/A', 'N/A']
# 2           ['N/A']
# 3            [None]
# 4            [None]
# 5      [None, None]
# 6           ['N/A']
# 7           ['GPA']
# 8           ['N/A']
# 9      [None, None]
# Name: result_types, dtype: object
# Raw data sample for column result_types in test_df:
# 0                [None]
# 1        ['GPA', 'GPA']
# 2               ['N/A']
# 3        ['N/A', 'N/A']
# 4               ['N/A']
# 5               ['N/A']
# 6    [None, None, None]
# 7               ['N/A']
# 8        ['GPA', 'GPA']
# 9        ['N/A', 'N/A']
# Name: result_types, dtype: object
# Raw data sample for column professional_company_names in train_df:
# 0                                        ['Coca-COla']
# 1                                  ['BIB Consultancy']
# 2                                ['Axis Bank Limited']
# 3    ['Company Name ï¼ City , State', 'Company Name...
# 4    ['Company Name', 'Company Name', 'Company Name...
# 5              ['N/A', 'Company Name', 'Company Name']
# 6                                      ['Remiro Amio']
# 7     ['Company Name', 'Company Name', 'Company Name']
# 8            ['AMZ Loans and Mortgages ERC Analytics']
# 9                        ['Daffodil Software Pvt Ltd']
# Name: professional_company_names, dtype: object
# Raw data sample for column professional_company_names in test_df:
# 0                                        ['Coca-COla']
# 1              ['Company Name', 'Company Name', 'N/A']
# 2                                     ['LT Solutions']
# 3                           ['Eximius Design Pvt ltd']
# 4    ['iNyra Nursing Home', 'Caribo Hotels & Casinos']
# 5    ['Company Name', 'Company Name', 'Company Name...
# 6    ['Company Name', 'Company Name', 'Company Name...
# 7                                        ['Tata Sons']
# 8    ['Company Name', 'Company Name', 'Company Name...
# 9    ['Company Name', 'Company Name', 'Company Name...
# Name: professional_company_names, dtype: object

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1212 entries, career_objective to professional_company_names_Magicpin
# dtypes: float64(14), int64(1178), object(20)
# memory usage: 70.6+ MB

# %%
# Define text columns
# text_cols = [
#     'career_objective',
#     'responsibilities',
#     'educationaL_requirements',
#     'related_skils_in_job',
#     'certification_skills',
#     'extra_curricular_activity_types',
#     '﻿job_position_name'
# ]
text_cols = [
    'career_objective',
    'responsibilities',
    'educationaL_requirements',
    'related_skils_in_job',
    '﻿job_position_name'
]
# Encode text features using TF-IDF and SVD
train_df, test_df, svd_cols = extract_text_features_tf_idf_svd_scaled(
    train_df, test_df, text_cols, max_features=500, n_components=50
)
# Out:
# Processing TF-IDF for column: career_objective
# Processing TF-IDF for column: responsibilities
# Processing TF-IDF for column: educationaL_requirements
# Processing TF-IDF for column: related_skils_in_job
# Processing TF-IDF for column: ﻿job_position_name

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1457 entries, educational_institution_name to ﻿job_position_name_svd_scaled_49
# dtypes: float64(264), int64(1178), object(15)
# memory usage: 84.9+ MB

# %%
numerical_cols
# Out:
# ['matched_score',
#  'education_level',
#  'numeric_result',
#  'education_match',
#  'required_years',
#  'total_experience_months',
#  'experience_match',
#  'skill_overlap',
#  'skill_coverage',
#  'skill_importance_score',
#  'position_match',
#  'objective_sentiment',
#  'objective_length',
#  'resp_length',
#  'resp_match',
#  'skill_edu_interaction',
#  'skill_exp_interaction',
#  'edu_exp_interaction',
#  'position_skill_match',
#  'position_edu_interaction']

# %%
train_st,test_st=train_df,test_df
train_st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1457 entries, educational_institution_name to ﻿job_position_name_svd_scaled_49
# dtypes: float64(264), int64(1178), object(15)
# memory usage: 84.9+ MB

# %%
train_st,test_st=train_df,test_df

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1457 entries, educational_institution_name to ﻿job_position_name_svd_scaled_49
# dtypes: float64(264), int64(1178), object(15)
# memory usage: 84.9+ MB

# %%
train_df,test_df=train_st,test_st
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1457 entries, educational_institution_name to ﻿job_position_name_svd_scaled_49
# dtypes: float64(264), int64(1178), object(15)
# memory usage: 84.9+ MB

# %%
train_df, test_df = emphasize_numerical_features(train_df, test_df, numerical_cols, svd_cols, weight_factor=10.0)
# Out:
# Final numerical columns (including one-hot encoded): ['education_level', 'numeric_result', 'education_match', 'required_years', 'total_experience_months', 'experience_match', 'skill_overlap', 'skill_coverage', 'skill_importance_score', 'position_match', 'objective_sentiment', 'objective_length', 'resp_length', 'resp_match', 'skill_edu_interaction', 'skill_exp_interaction', 'edu_exp_interaction', 'position_skill_match', 'position_edu_interaction', 'educational_institution_name_The Amity School of Engineering & Technology (ASET), Noida', 'educational_institution_name_Delhi University - Hansraj College', 'educational_institution_name_Birla Institute of Technology (BIT), Ranchi', 'educational_institution_name_Martinez Adult Education, Business Training Center ï¼ City , State', 'educational_institution_name_Kent State University', 'educational_institution_name_Glen Oaks High School', 'educational_institution_name_DJR College and University', 'educational_institution_name_POLYTECHNIC UNIVERSITY OF PUERTO RICO', 'educational_institution_name_Nagpur University', 'educational_institution_name_Dr. Virendra Swaroop Institute of Computer Studies, Kanpur', 'educational_institution_name_Pranveer Singh Institute of Technology, Kanpur', 'educational_institution_name_CALIFORNIA STATE UNIVERSITY, HAYWARD', 'educational_institution_name_UNIVERSITY OF MARYLAND, COLLEGE PARK', 'educational_institution_name_COLLEGE OF ARTS, SCIENCE, AND TECHNOLOGY', 'educational_institution_name_NARSEE MONJEE INSTITUTE', 'educational_institution_name_Raja Kashwant Singh General College', 'educational_institution_name_Dayalbagh Educational Institute, Dayalbagh, Agra', "educational_institution_name_St. Clare's Senior Secondary School, Agra", 'educational_institution_name_University of Santa Clara', 'educational_institution_name_CDAC ACTS', 'educational_institution_name_University of Phoenix Texas', 'educational_institution_name_IIIT D&M Kancheepuram, Chennai', 'educational_institution_name_Raja Birsimbal College, Ranchi', 'educational_institution_name_TEMPLE UNIVERSITY', 'educational_institution_name_University of Northern Iowa', 'educational_institution_name_Hawkeye Community College', 'educational_institution_name_V.V.I.T', 'educational_institution_name_Monterey Peninsula College', 'educational_institution_name_San Francisco Police Academy', 'educational_institution_name_KVoCT, Pune', 'educational_institution_name_Princeton International School of Mathematics and Science', 'educational_institution_name_New York University', 'educational_institution_name_Shaheed Bhagat Singh College (M), University of Delhi', 'educational_institution_name_Indian Statistical Institute (ISI), Delhi', 'educational_institution_name_Illinois Institute of Technology', 'educational_institution_name_National Institute of Technology', 'educational_institution_name_Jawaharlal Nehru University', 'educational_institution_name_McFord University', 'educational_institution_name_University Of Phoenix College', 'educational_institution_name_SMV Institute of Technology', 'educational_institution_name_University of Toronto', 'educational_institution_name_University of Pittsburgh', 'educational_institution_name_KLE College of Engineering, Belagavi', 'educational_institution_name_IISc', 'educational_institution_name_IIIT Bangalore', 'educational_institution_name_LPU, Chandigarh', 'educational_institution_name_Southeastern Louisiana University', 'educational_institution_name_American Intercontinental University', 'educational_institution_name_Florida International University', 'educational_institution_name_State of Ohio', 'educational_institution_name_Navy', 'educational_institution_name_SSGM, Maharashtra', 'educational_institution_name_International Institute of Information Technology (IIIT), Bangalore', 'educational_institution_name_Indian Institute of Technology', 'educational_institution_name_Devi Ahilya University', 'educational_institution_name_Coursera - Stanford', 'educational_institution_name_Yo ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1442 entries, education_level to matched_score
# dtypes: float64(1442)
# memory usage: 84.0 MB

# %%
numerical_cols
# Out:
# ['matched_score',
#  'education_level',
#  'numeric_result',
#  'education_match',
#  'required_years',
#  'total_experience_months',
#  'experience_match',
#  'skill_overlap',
#  'skill_coverage',
#  'skill_importance_score',
#  'position_match',
#  'objective_sentiment',
#  'objective_length',
#  'resp_length',
#  'resp_match',
#  'skill_edu_interaction',
#  'skill_exp_interaction',
#  'edu_exp_interaction',
#  'position_skill_match',
#  'position_edu_interaction']

# %%
target_col='matched_score'
numerical_cols = [col for col in numerical_cols if col != target_col]
outlier_cols=numerical_cols+svd_cols
#outlier_cols

# %%
drop_cols = ['matched_score', 'ID']

feature_cols = [
    c for c in train_df.columns
    if c not in drop_cols
        and (train_df[c].dtype in [np.float64, np.int64, np.float32, np.int32])
]



# Fill missing numeric values
train_df, test_df = prepare_features(train_df, test_df)
outlier_threshold = 3.0  # Define threshold for identifying outliers (z-score method)
        
def handle_outliers(df, columns):
    for col in columns:
        if df[col].dtype in [np.float64, np.int64, np.float32, np.int32]:
            # Calculate z-scores
            z_scores = (df[col] - df[col].mean()) / df[col].std()
            
            # Winsorize extreme values (cap outliers)
            upper_limit = df[col].mean() + outlier_threshold * df[col].std()
            lower_limit = df[col].mean() - outlier_threshold * df[col].std()
            
            df[col] = np.clip(df[col], lower_limit, upper_limit)
    return df


# Apply outlier handling on both train and test sets
train_df = handle_outliers(train_df, outlier_cols)
test_df = handle_outliers(test_df, outlier_cols)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1442 entries, education_level to matched_score
# dtypes: float64(1442)
# memory usage: 84.0 MB

# %%
train_st,test_st=train_df,test_df

# %%
train_df,test_df=train_st,test_st
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 1442 entries, education_level to matched_score
# dtypes: float64(1442)
# memory usage: 84.0 MB

# %%
from sklearn.ensemble import RandomForestRegressor

# def select_important_features(train_df, test_df, target, top_k=20):
#     """
#     Select top `k` features based on importance using a random forest.
#     """
#     # Split into features and target
#     X_train = train_df.drop(columns=[target])
#     y_train = train_df[target]
    
#     # Train a random forest to get feature importance
#     model = RandomForestClassifier(random_state=42)
#     model.fit(X_train, y_train)
    
#     # Get feature importance
#     feature_importance = pd.Series(model.feature_importances_, index=X_train.columns)
#     important_features = feature_importance.nlargest(top_k).index
    
#     # Filter top features
#     train_df = train_df[important_features]
#     test_df = test_df[important_features]
    
#     return train_df, test_df


# Use Random Forest to estimate feature importance
model = RandomForestRegressor(random_state=42)
model.fit(train_df[feature_cols], train_df[target_col])

# Feature importance
feature_importances = pd.Series(model.feature_importances_, index=feature_cols)
print("Feature Importances:")
print(feature_importances)

# Select features based on importance threshold
important_features = feature_importances[feature_importances > 0.0002].index.tolist()
print(f"Selected features: {len(important_features)} out of {len(feature_cols)}")

# Drop less important features
train_df = train_df[important_features + [target_col]]
test_df = test_df[important_features]
# Out:
# Feature Importances:
# education_level                                                                                                                                                                                                                  6.605271e-03
# numeric_result                                                                                                                                                                                                                   3.952366e-03
# education_match                                                                                                                                                                                                                  3.808951e-02
# required_years                                                                                                                                                                                                                   3.843451e-03
# total_experience_months                                                                                                                                                                                                          0.000000e+00
# experience_match                                                                                                                                                                                                                 0.000000e+00
# skill_overlap                                                                                                                                                                                                                    0.000000e+00
# skill_coverage                                                                                                                                                                                                                   0.000000e+00
# skill_importance_score                                                                                                                                                                                                           0.000000e+00
# position_match                                                                                                                                                                                                                   2.836040e-02
# objective_sentiment                                                                                                                                                                                                              1.408292e-03
# objective_length                                                                                                                                                                                                                 2.112431e-03
# resp_length                                                                                                                                                                                                                      9.874073e-02
# resp_match                                                                                                                                                                                                                       0.000000e+00
# skill_edu_interaction                                                                                                                                                                                                            0.000000e+00
# skill_exp_interaction                                                                                                                                                                                                            0.000000e+00
# edu_exp_interaction                                                                                                                                                                                                              0.000000e+00
# position_skill_match                                                                                                                                                                                                             0.000000e+00
# position_edu_interaction                                                                                                                                                                                                         3.379995e-02
# educational_institution_name_The Amity School of Engineering & Technology (ASET), Noida                                                                                                                                          5.648884e-07
# educational_institution_name_Delhi University - Hansraj College                                                                                                                                                                  7.681680e-07
# educational_institution_name_Birla Institute of Technology (BIT), Ranchi                                                                                                                                                         2.987638e-05
# educational_institution_name_Martinez Adult Education, Business Training Center ï¼ City , State                                                                                                                                  2.051126e-06
# educational_institution_name_Kent State University                                                                                                                                                                               9.457811e-05
# educational_institution_name_Glen Oaks High School                                                                                                                                                                               1.857241e-07
# educational_institution_name_DJR College and University                                                                                                                                                                          4.097108e-04
# educational_institution_name_POLYTECHNIC UNIVERSITY OF PUERTO RICO                                                                                                                                                               5.227498e-06
# educational_institution_name_Nagpur University                                                                                                                                                                                   2.637699e-05
# educational_institution_name_Dr. Virendra Swaroop Institute of Computer Studies, Kanpur                                                                                                                                          6.628686e-07
# educational_institution_name_Pranveer Singh Institute of Technology, Kanpur                                                                                                                                                      1.351561e-05
# educational_institution_name_CALIFORNIA STATE UNIVERSITY, HAYWARD                                                                                                                                                                1.209668e-06
# educational_institution_name_UNIVERSITY OF MARYLAND, COLLEGE PARK                                                                                                                                                                1.339986e-06
# educational_institution_name_COLLEGE OF ARTS, SCIENCE, AND TECHNOLOGY                                                                                                                                                            9.644610e-08
# educational_institution_name_NARSEE MONJEE INSTITUTE                                                                                                                                                                             1.867857e-06
# educational_institution_name_Raja Kashwant Singh General College                                                                                                                                                                 1.974921e-04
# educational_institution_name_Dayalbagh Educational Institute, Dayalbagh, Agra                                                                                                                                                    5.675555e-05
# educational_institution_name_St. Clare's Senior Secondary School, Agra                                                                                                                                                           3.128144e-07
# educational_institution_name_University of Santa Clara                                                                                                                                                                           2.824269e-06
# educational_institution_name_CDAC ACTS                                                                                                                                                                                           1.833350e-05
# educational_institution_name_University of Phoenix Texas                                                                                                                                                                         4.984589e-06
# educational_institution_name_IIIT D&M Kancheepuram, Chennai                                                                                                                                                                      1.366996e-06
# educational_institution_name_Raja Birsimbal College, Ranchi                                                                                                                                                                      2.445848e-05
# educational_institution_name_TEMPLE UNIVERSITY                                                                                                                                                                                   6.480837e-04
# educational_institution_name_University of Northern Iowa                                                                                                                                                                         1.524973e-05
# educational_institution_name_Hawkeye Community College                                                                                                                                                                           3.834556e-05
# educational_institution_name_V.V.I.T                                                                                                                                                                                             1.778939e-07
# educational_institution_name_Monterey Peninsula College                                                                                                                                                                          7.713096e-06
# educational_institution_name_San Francisco Police Academy                                                                                                                                                                        2.300231e-08
# educational_institution_name_KVoCT, Pune                                                                                                                                                                                         1.424119e-06
# educational_institution_name_Princeton International School of Mathematics and Science                                                                                                                                           1.372963e-06
# educational_institution_name_New York University                                                                                                                                                                                 1.544043e-05
# educational_institution_name_Shaheed Bhagat Singh College (M), University of Delhi                                                                                                                                               6.738144e-06
# educational_institution_name_Indian Statistical Institute (ISI), Delhi                                                                                                                                                           1.647569e-05
# educational_institution_name_Illinois Institute of Technology                                                                                                                                                                    9.166700e-06
# educational_institution_name_National Institute of Technology                                                                                                                                                                    6.636704e-06
# educational_institution_name_Jawaharlal Nehru University                                                                                                                                                                         1.095790e-06
# educational_institution_name_McFord University                                                                                                                                                                                   8.053208e-06
# educational_institution_name_University Of Phoenix College                                                                                                                                                                       1.226586e-05
# educational_institution_name_SMV Institute of Technology                                                                                                                                                                         2.713322e-05
# educational_institution_name_University of Toronto                                                                                                                                                                               5.072261e-05
# educational_institution_name_University of Pittsburgh                                                                                                                                                                            7.231045e-05
# educational_institution_name_KLE College of Engineering, Belagavi                                                                                                                                                                1.787280e-06
# educational_institution_name_IISc                                                                                                                                                                                                6.234657e-07
# educational_institution_name_IIIT Bangalore                                                                                                                                                                                      4.949331e-06
# educational_institution_name_LPU, Chandigarh                                                                                                                                                                                     1.988471e-06
# educational_institution_name_Southeastern Louisiana University                                                                                                                                                                   3.426926e-04
# educational_institution_name_American Intercontinental University                                                                                                                                                                6.097351e-06
# educational_institution_name_Florida International University                                                                                                                                                                    9.007553e-05
# educational_institution_name_State of Ohio                                                                                                                                                                                       1.630740e-06
# educational_institution_name_Navy                                                                                                                                                                                                2.182910e-06
# educational_institution_name_SSGM, Maharashtra                                                                                                                                                                                   2.941131e-07
# educational_institution_name_International Institute of Information Technology (IIIT), Bangalore                                                                                                                                 3.664618e-06
# educational_institution_name_Indian Institute of Technology                                                                                                                                                                      1.271649e-06
# educational_institution_name_Devi Ahilya University                                                                                                                                                                              3.786722e-04
# educational_institution_name_Coursera - Stanford                                                                                                                                                                                 1.410313e-06
# educational_institution_name_York University, Toronto                                                                                                                                                                            2.942246e-07
# educational_institution_name_University of Michigan Dearborn                                                                                                                                                                     1.978505e-05
# educational_institution_name_Visvesvaraya Technological University                                                                                                                                                               3.112281e-05
# educational_institution_name_NORTMEAD HIGH SCHOOL                                                                                                                                                                                4.363714e-07
# educational_institution_name_UNIVERSITY OF NEW SOUTH WALES (UNSW)                                                                                                                                                                1.049717e-07
# educational_institution_name_Mesa High School                                                                                                                                                                                    7.817896e-06
# educational_institution_name_Fox School of Business, Temple University                                                                                                                                                           3.510394e-05
# educational_institution_name_Shivaji College                                                                                                                                                                                     6.019925e-06
# educational_institution_name_Indira Gandhi National Open University                                                                                                                                                              1.840108e-06
# educational_institution_name_Portland State University                                                                                                                                                                           3.538302e-05
# educational_institution_name_McCallum Graduate School at Bentley University                                                                                                                                                      2.513111e-05
# educational_institution_name_Bentley University                                                                                                                                                                                  3.482528e-06
# educational_institution_name_West Virginia State University                                                                                                                                                                      5.832621e-05
# educational_institution_name_Marshall University                                                                                                                                                                                 4.884733e-04
# educational_institution_name_Center College                                                                                                                                                                                      5.267726e-05
# educational_institution_name_Denver High School                                                                                                                                                                                  8.516925e-09
# educational_institution_name_Front Range Community College                                                                                                                                                                       7.083926e-07
# educational_institution_name_Harvard University                                                                                                                                                                                  1.392439e-06
# educational_institution_name_Bob Jones University                                                                                                                                                                                7.151447e-07
# educational_institution_name_St Josephs College of Arts and Science Bengaluru                                                                                                                                                    4.546626e-08
# educational_institution_name_ARIZONA STATE UNIVERSITY                                                                                                                                                                            3.756841e-06
# educational_institution_name_SP University                                                                                                                                                                                       3.192305e-06
# educational_institution_name_KCCE University                                                                                                                                                                                     7.719593e-06
# educational_institution_name_Madras University                                                                                                                                                                                   3.643178e-06
# educational_institution_name_SRM University (SRMU)                                                                                                                                                                               1.124883e-05
# educational_institution_name_Oklahoma Jr. College                                                                                                                                                                                3.261481e-07
# educational_institution_name_Maulana Malviya College for Informatics                                                                                                                                                             3.903129e-06
# educational_institution_name_Penn State                                                                                                                                                                                          7.534064e-07
# educational_institution_name_Faith Christian Academy                                                                                                                                                                             1.082394e-06
# educational_institution_name_University of Texas                                                                                                                                                                                 3.094981e-05
# educational_institution_name_Arizona State University                                                                                                                                                                            9.745787e-05
# educational_institution_name_Lucknow University                                                                                                                                                                                  5.380472e-06
# educational_institution_name_Oklahoma Christian University                                                                                                                                                                       1.243600e-06
# educational_institution_name_Sastra University, Tanjore Tamil Nadu                                                                                                                                                               2.267013e-07
# educational_institution_name_SPPU                                                                                                                                                                                                8.555293e-07
# educational_institution_name_Indian Institute of Technology (IIT), Kharagpur                                                                                                                                                     2.696873e-06
# educational_institution_name_University of Mangalore                                                                                                                                                                             3.726458e-06
# educational_institution_name_Indian Institute of Technology (IIT), Mumbai                                                                                                                                                        1.132403e-06
# educational_institution_name_ITT Techinical Institute                                                                                                                                                                            2.532335e-06
# educational_institution_name_Solano College                                                                                                                                                                                      1.351745e-05
# educational_institution_name_Sl Thala Model college                                                                                                                                                                              3.193620e-07
# educational_institution_name_Georgia Institute of Technology                                                                                                                                                                     3.995083e-06
# educational_institution_name_Rutgers University                                                                                                                                                                                  1.449971e-05
# educational_institution_name_Mumbai University                                                                                                                                                                                   4.556977e-06
# educational_institution_name_MamCO University                                                                                                                                                                                    3.436440e-07
# educational_institution_name_Vidyasagar University                                                                                                                                                                               1.854493e-06
# educational_institution_name_Mohan Lal Sukhadia University                                                                                                                                                                       1.719495e-06
# educational_institution_name_North Dakota State University                                                                                                                                                                       7.606093e-06
# educational_institution_name_ITT Technical Institute                                                                                                                                                                             5.158212e-06
# educational_institution_name_Sri Venkateshwara University (SVU)                                                                                                                                                                  1.874568e-07
# educational_institution_name_University of North Carolina                                                                                                                                                                        1.191935e-04
# educational_institution_name_N/A                                                                                                                                                                                                 3.712989e-05
# educational_institution_name_DeVry University                                                                                                                                                                                    1.826802e-04
# educational_institution_name_Stephen F. Austin State University                                                                                                                                                                  4.486512e-06
# educational_institution_name_Thakur Shiv Kumar Singh Memorial Engineering College                                                                                                                                                1.126559e-05
# educational_institution_name_Institute for Advanced Computing and Software Development                                                                                                                                           2.151618e-05
# educational_institution_name_University of British Columbia                                                                                                                                                                      5.061143e-05
# educational_institution_name_Maury High School                                                                                                                                                                                   1.035902e-04
# educational_institution_name_Lamar Institute of Technology                                                                                                                                                                       8.940753e-05
# educational_institution_name_Birla Institute of Technology and Science (BITS), Pilani                                                                                                                                            3.022772e-07
# educational_institution_name_Punjab Technical University                                                                                                                                                                         2.840668e-06
# educational_institution_name_SHRI GURU GOBIND SINGHJI COLLEGE OF ENGINEERING AND TECHNOLOGY, NANED                                                                                                                               2.188632e-06
# educational_institution_name_University of Idaho - School of Engineering                                                                                                                                                         2.364308e-06
# educational_institution_name_IIT Kharagpur                                                                                                                                                                                       0.000000e+00
# educational_institution_name_Rose-Hulman Institute of Technology                                                                                                                                                                 9.233701e-06
# educational_institution_name_University of Maryland, University College                                                                                                                                                          2.919382e-07
# educational_institution_name_University of Maryland                                                                                                                                                                              4.928004e-06
# educational_institution_name_Manipal University                                                                                                                                                                                  1.620474e-05
# educational_institution_name_University of *Strong Vincent HS                                                                                                                                                                    4.331089e-05
# educational_institution_name_Intermediate Electronic Principles, Keesler AFB, MS                                                                                                                                                 3.129172e-05
# educational_institution_name_*Telephone Central Office Repair                                                                                                                                                                    3.355399e-05
# educational_institution_name_*HAZMAT Familiarization/Safety Transport                                                                                                                                                            6.480565e-05
# educational_institution_name_*Forward Area Alerting Radar Repairer                                                                                                                                                               5.489521e-06
# educational_institution_name_California University                                                                                                                                                                               2.185906e-05
# educational_institution_name_East Boston High School                                                                                                                                                                             4.883936e-06
# educational_institution_name_University of Warsaw                                                                                                                                                                                1.642508e-04
# educational_institution_name_University at Buffalo, The State University of New York                                                                                                                                             6.211715e-07
# educational_institution_name_University of Mumbai                                                                                                                                                                                1.277639e-06
# educational_institution_name_Treasure Valley Community College                                                                                                                                                                   1.954979e-04
# educational_institution_name_Worland High School                                                                                                                                                                                 1.742212e-05
# educational_institution_name_Pepperdine University, Graziadio School of Business and Management                                                                                                                                  2.995529e-04
# educational_institution_name_University of New Orleans                                                                                                                                                                           2.460408e-04
# educational_institution_name_Inderprastha Engineering College Ghaziabad                                                                                                                                                          1.132782e-05
# educational_institution_name_Syracuse University                                                                                                                                                                                 1.618038e-06
# educational_institution_name_Thapar University                                                                                                                                                                                   8.448102e-07
# educational_institution_name_Delhi Public School                                                                                                                                                                                 2.414164e-06
# educational_institution_name_Indiana University                                                                                                                                                                                  8.373709e-06
# educational_institution_name_University of Evansville                                                                                                                                                                            1.451163e-06
# educational_institution_name_Villanova University                                                                                                                                                                                1.057183e-06
# educational_institution_name_National Institute Of Science And Technology, Rourkela                                                                                                                                              4.084285e-06
# educational_institution_name_Cornell University, Department of Computer Science                                                                                                                                                  7.527708e-07
# educational_institution_name_Tel Aviv University, Israel                                                                                                                                                                         2.978686e-06
# educational_institution_name_DBB University, Himachal                                                                                                                                                                            1.530007e-06
# educational_institution_name_Oakland University                                                                                                                                                                                  1.972348e-04
# educational_institution_name_Macomb Community College                                                                                                                                                                            1.125085e-04
# educational_institution_name_University of California at Santa Barbara                                                                                                                                                           6.226641e-04
# educational_institution_name_University of Southern California, Viterbi School of Engineering, CACS Research Group                                                                                                               2.297017e-05
# educational_institution_name_The University of Tokyo, User Interface Research Group                                                                                                                                              3.478410e-05
# educational_institution_name_The University of Tokyo                                                                                                                                                                             3.421607e-05
# educational_institution_name_KELLER GRADUATE SCHOOL OF MANAGEMENT, DEVRY UNIVERSITY                                                                                                                                              1.297192e-06
# educational_institution_name_MINNESOTA STATE UNIVERSITY                                                                                                                                                                          1.365408e-06
# educational_institution_name_NORTHWEST IOWA COMMUNITY COLLEGE                                                                                                                                                                    7.849920e-07
# educational_institution_name_Eastern New Mexico University                                                                                                                                                                       3.234410e-06
# educational_institution_name_Embry-Riddle Aeronautical University                                                                                                                                                                5.932205e-06
# educational_institution_name_Enterprise Community College                                                                                                                                                                        5.622112e-07
# educational_institution_name_University of California, Santa Cruz                                                                                                                                                                1.729783e-04
# educational_institution_name_Claremont Graduate University                                                                                                                                                                       4.515760e-05
# educational_institution_name_Mount St. Mary's University                                                                                                                                                                         2.774672e-05
# educational_institution_name_Jaipur University                                                                                                                                                                                   8.031444e-07
# educational_institution_name_Southeastern Louisiana University (SLU)                                                                                                                                                             1.551947e-05
# educational_institution_name_Dr. Jagjiban Rao Engineering College                                                                                                                                                                5.926680e-07
# educational_institution_name_KTM College, Nashik (affiliated with Lucknow University)                                                                                                                                            9.173524e-06
# educational_institution_name_SPP University, Pune                                                                                                                                                                                4.645967e-06
# educational_institution_name_Vellore Institute of Technology (VIT)                                                                                                                                                               5.704364e-07
# educational_institution_name_Andrés Bello Catholic University                                                                                                                                                                    3.605497e-06
# educational_institution_name_Saint Anthony of La Florida                                                                                                                                                                         1.937555e-06
# educational_institution_name_Fred Pryor Seminars & Career Track                                                                                                                                                                  1.366227e-06
# educational_institution_name_KPMG                                                                                                                                                                                                9.426275e-06
# educational_institution_name_University of Maryland University College                                                                                                                                                           1.866926e-04
# educational_institution_name_Strayer University                                                                                                                                                                                  1.180754e-04
# educational_institution_name_CITY UNIVERSITY BUSINESS SCHOOL                                                                                                                                                                     1.193491e-04
# educational_institution_name_THE UNIVERSITY OF HULL                                                                                                                                                                              1.048675e-04
# educational_institution_name_Temple University                                                                                                                                                                                   3.517472e-06
# educational_institution_name_Narsee Monjee Institute of Management Studies                                                                                                                                                       1.832833e-05
# educational_institution_name_Colorado Technical University                                                                                                                                                                       3.932314e-05
# educational_institution_name_Rowan Cabarrus Community College                                                                                                                                                                    5.976692e-05
# ...
# related_skils_in_job_svd_scaled_33                                                                                                                                                                                               3.757002e-03
# related_skils_in_job_svd_scaled_34                                                                                                                                                                                               4.148834e-03
# related_skils_in_job_svd_scaled_35                                                                                                                                                                                               3.929961e-03
# related_skils_in_job_svd_scaled_36                                                                                                                                                                                               3.294506e-03
# related_skils_in_job_svd_scaled_37                                                                                                                                                                                               2.956939e-03
# related_skils_in_job_svd_scaled_38                                                                                                                                                                                               3.043488e-03
# related_skils_in_job_svd_scaled_39                                                                                                                                                                                               3.862122e-03
# related_skils_in_job_svd_scaled_40                                                                                                                                                                                               4.082551e-03
# related_skils_in_job_svd_scaled_41                                                                                                                                                                                               4.577269e-03
# related_skils_in_job_svd_scaled_42                                                                                                                                                                                               3.090408e-03
# related_skils_in_job_svd_scaled_43                                                                                                                                                                                               3.207357e-03
# related_skils_in_job_svd_scaled_44                                                                                                                                                                                               6.447769e-03
# related_skils_in_job_svd_scaled_45                                                                                                                                                                                               3.224638e-03
# related_skils_in_job_svd_scaled_46                                                                                                                                                                                               2.777177e-03
# related_skils_in_job_svd_scaled_47                                                                                                                                                                                               4.377548e-03
# related_skils_in_job_svd_scaled_48                                                                                                                                                                                               3.346062e-03
# related_skils_in_job_svd_scaled_49                                                                                                                                                                                               4.278534e-03
# ﻿job_position_name_svd_scaled_0                                                                                                                                                                                                  9.166519e-04
# ﻿job_position_name_svd_scaled_1                                                                                                                                                                                                  1.702254e-03
# ﻿job_position_name_svd_scaled_2                                                                                                                                                                                                  6.814194e-04
# ﻿job_position_name_svd_scaled_3                                                                                                                                                                                                  2.344125e-03
# ﻿job_position_name_svd_scaled_4                                                                                                                                                                                                  8.979340e-04
# ﻿job_position_name_svd_scaled_5                                                                                                                                                                                                  3.317546e-03
# ﻿job_position_name_svd_scaled_6                                                                                                                                                                                                  9.527124e-04
# ﻿job_position_name_svd_scaled_7                                                                                                                                                                                                  7.152009e-05
# ﻿job_position_name_svd_scaled_8                                                                                                                                                                                                  1.080313e-03
# ﻿job_position_name_svd_scaled_9                                                                                                                                                                                                  1.035683e-04
# ﻿job_position_name_svd_scaled_10                                                                                                                                                                                                 6.618803e-04
# ﻿job_position_name_svd_scaled_11                                                                                                                                                                                                 6.282277e-04
# ﻿job_position_name_svd_scaled_12                                                                                                                                                                                                 8.704149e-04
# ﻿job_position_name_svd_scaled_13                                                                                                                                                                                                 6.757084e-04
# ﻿job_position_name_svd_scaled_14                                                                                                                                                                                                 7.283715e-04
# ﻿job_position_name_svd_scaled_15                                                                                                                                                                                                 1.851112e-05
# ﻿job_position_name_svd_scaled_16                                                                                                                                                                                                 6.976377e-04
# ﻿job_position_name_svd_scaled_17                                                                                                                                                                                                 1.207956e-03
# ﻿job_position_name_svd_scaled_18                                                                                                                                                                                                 9.973759e-04
# ﻿job_position_name_svd_scaled_19                                                                                                                                                                                                 5.204960e-04
# ﻿job_position_name_svd_scaled_20                                                                                                                                                                                                 1.642742e-03
# ﻿job_position_name_svd_scaled_21                                                                                                                                                                                                 8.050262e-04
# ﻿job_position_name_svd_scaled_22                                                                                                                                                                                                 6.647403e-04
# ﻿job_position_name_svd_scaled_23                                                                                                                                                                                                 5.691793e-04
# ﻿job_position_name_svd_scaled_24                                                                                                                                                                                                 1.859315e-03
# ﻿job_position_name_svd_scaled_25                                                                                                                                                                                                 6.866804e-04
# ﻿job_position_name_svd_scaled_26                                                                                                                                                                                                 5.614532e-04
# ﻿job_position_name_svd_scaled_27                                                                                                                                                                                                 1.212407e-03
# ﻿job_position_name_svd_scaled_28                                                                                                                                                                                                 1.601595e-03
# ﻿job_position_name_svd_scaled_29                                                                                                                                                                                                 6.439500e-04
# ﻿job_position_name_svd_scaled_30                                                                                                                                                                                                 1.842324e-03
# ﻿job_position_name_svd_scaled_31                                                                                                                                                                                                 1.125590e-03
# ﻿job_position_name_svd_scaled_32                                                                                                                                                                                                 8.010861e-04
# ﻿job_position_name_svd_scaled_33                                                                                                                                                                                                 4.467704e-03
# ﻿job_position_name_svd_scaled_34                                                                                                                                                                                                 8.859835e-04
# ﻿job_position_name_svd_scaled_35                                                                                                                                                                                                 2.185471e-03
# ﻿job_position_name_svd_scaled_36                                                                                                                                                                                                 1.355363e-03
# ﻿job_position_name_svd_scaled_37                                                                                                                                                                                                 6.061507e-04
# ﻿job_position_name_svd_scaled_38                                                                                                                                                                                                 6.468703e-04
# ﻿job_position_name_svd_scaled_39                                                                                                                                                                                                 6.814522e-04
# ﻿job_position_name_svd_scaled_40                                                                                                                                                                                                 5.726721e-04
# ﻿job_position_name_svd_scaled_41                                                                                                                                                                                                 1.092060e-03
# ﻿job_position_name_svd_scaled_42                                                                                                                                                                                                 1.171940e-03
# ﻿job_position_name_svd_scaled_43                                                                                                                                                                                                 6.076235e-04
# ﻿job_position_name_svd_scaled_44                                                                                                                                                                                                 8.387658e-04
# ﻿job_position_name_svd_scaled_45                                                                                                                                                                                                 7.164153e-04
# ﻿job_position_name_svd_scaled_46                                                                                                                                                                                                 1.197589e-03
# ﻿job_position_name_svd_scaled_47                                                                                                                                                                                                 7.930873e-04
# ﻿job_position_name_svd_scaled_48                                                                                                                                                                                                 5.391247e-04
# ﻿job_position_name_svd_scaled_49                                                                                                                                                                                                 5.621353e-04
# dtype: float64
# Selected features: 329 out of 1441

# %%
print("md")
# Out:
# md

# %%
train_st_imp,test_st_imp=train_df,test_df

# %%
train_st_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 330 entries, education_level to matched_score
# dtypes: float64(330)
# memory usage: 19.2 MB

# %%
train_df,test_df=train_st_imp,test_st_imp

# %%
# Define target and features
target_col = 'matched_score'
if target_col not in train_df.columns:
    raise ValueError(f"{target_col} not found in train_df columns!")

# Drop rows with missing target
train_df = train_df.dropna(subset=[target_col])

# %%
X = train_df.copy()
y = train_df[target_col].values
X_test = test_df.copy()

# Define feature columns
drop_cols = ['matched_score', 'ID']
feature_cols = [
    c for c in train_df.columns
    if c not in drop_cols
        and (train_df[c].dtype in [np.float64, np.int64, np.float32, np.int32])
]
print(f"Total features: {len(feature_cols)}")

# Scale features

# Scale features
scaler = RobustScaler()
X[feature_cols] = scaler.fit_transform(X[feature_cols])
X_test[feature_cols] = scaler.transform(X_test[feature_cols])

# scaler = StandardScaler()
# X[feature_cols] = scaler.fit_transform(X[feature_cols])
# X_test[feature_cols] = scaler.transform(X_test[feature_cols])

# Re-assign after scaling
train_df = X
test_df = X_test
# Out:
# Total features: 329

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7635 entries, 0 to 7634
# Columns: 330 entries, education_level to matched_score
# dtypes: float64(330)
# memory usage: 19.2 MB

# %%
numerical = train_df.select_dtypes(include=['int64', 'float64'])
numerical_cols = numerical.columns
Correlation = numerical.corr()

# %%
pd.set_option('display.max_rows', None)

# %%
from keras.models import Model
from keras.layers import Input, Dense, BatchNormalization, Activation, Add, Dropout
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
import numpy as np
import pandas as pd

# %%
def create_xnn(input_dim):
    """
    Create an Experimental Neural Network (XNN) model with fixed residual connections.
    """
    inputs = Input(shape=(input_dim,))
    
    # First hidden layer with BatchNorm, Swish activation, and Dropout
    x = Dense(256)(inputs)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Dropout(0.3)(x)

    # Residual connection: Use a Dense layer to match dimensions
    x_residual = Dense(128)(x)
    x_residual = BatchNormalization()(x_residual)
    x_residual = Activation('swish')(x_residual)
    x_residual = Dropout(0.2)(x_residual)

    # Project input tensor to match the residual dimension
    x = Dense(128)(x)  # Project the original tensor to 128 units
    x = Add()([x, x_residual])  # Now the shapes match

    # Third hidden layer
    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)
    x = Dropout(0.2)(x)

    # Output layer
    outputs = Dense(1, activation='linear')(x)

    # Define the model
    model = Model(inputs=inputs, outputs=outputs)

    # Compile the model
    model.compile(
        optimizer='adam',
        loss='mse',
        metrics=['mse']
    )
    
    return model

# %%
def cross_validate_and_train_xnn(train_df, features, target, test_df, n_folds=10, random_state=42):
    """
    Perform K-Fold Cross-Validation with XNN and then train on full dataset.
    """
    # Initialize KFold
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_state)
    
    # Initialize variables for predictions and metrics
    oof_preds_xnn = np.zeros(len(train_df))
    test_preds_xnn_cv = np.zeros(len(test_df))
    fold_mses_xnn = []
    
    # Perform K-Fold Cross-Validation
    for fold, (train_idx, val_idx) in enumerate(kf.split(train_df)):
        print(f'\nTraining fold {fold + 1} / {n_folds}')
        
        # Split data into training and validation folds
        X_train_fold = train_df.iloc[train_idx][features].values
        y_train_fold = train_df.iloc[train_idx][target].values
        X_val_fold = train_df.iloc[val_idx][features].values
        y_val_fold = train_df.iloc[val_idx][target].values
        
        # Create XNN model
        model = create_xnn(input_dim=len(features))
        
        # Early stopping
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

        # Train the model
        model.fit(
            X_train_fold, y_train_fold,
            validation_data=(X_val_fold, y_val_fold),
            epochs=200,
            batch_size=32,
            callbacks=[early_stopping],
            verbose=1
        )

        # Predict on validation set
        y_pred_xnn = model.predict(X_val_fold).flatten()
        mse_xnn = mean_squared_error(y_val_fold, y_pred_xnn)
        fold_mses_xnn.append(mse_xnn)
        print(f"Fold {fold + 1} XNN MSE: {mse_xnn:.6f}")
        oof_preds_xnn[val_idx] = y_pred_xnn

        # Predict on test set and accumulate
        test_preds_xnn_cv += model.predict(test_df[features].values).flatten() / n_folds
    
    # Calculate average MSE from cross-validation
    avg_mse_xnn = np.mean(fold_mses_xnn)
    print(f"\nAverage XNN Cross-Validation MSE: {avg_mse_xnn:.6f}")
    
    # Train final model on FULL dataset
    print("\n========== Training Final Model on Full Dataset ==========")
    # Prepare full training dataset
    X_train_full = train_df[features].values
    y_train_full = train_df[target].values
    
    # Create final XNN model
    final_model = create_xnn(input_dim=len(features))
    
    # Train the final model
    final_model.fit(
        X_train_full, y_train_full,
        epochs=200,
        batch_size=32,
        verbose=1
    )
    
    # Predict on test set with final model
    test_preds_xnn_final = final_model.predict(test_df[features].values).flatten()
    
    return test_preds_xnn_final, avg_mse_xnn, final_model

# %%
# Perform Cross-Validation and Full Dataset Training with XNN
print("\n========== Starting Cross-Validation with Experimental Neural Network ==========")
test_preds_xnn, mean_mse_xnn, final_xnn_model = cross_validate_and_train_xnn(
    train_df, 
    feature_cols, 
    target_col, 
    test_df
)

# Clip predictions to valid range
test_preds_xnn = np.clip(test_preds_xnn, 0, 1)

# Prepare submission
print("\nPreparing Submission...")
# Check if 'ID' column exists, rename or create if necessary
if 'ID' not in test_df.columns:
    if 'id' in test_df.columns:
        test_df.rename(columns={'id': 'ID'}, inplace=True)
    elif 'identifier' in test_df.columns:
        test_df.rename(columns={'identifier': 'ID'}, inplace=True)
    else:
        print("No 'ID' column found in test_df. Generating a sequential ID column...")
        test_df['ID'] = range(1, len(test_df) + 1)

# Ensure sample_submission has matching 'ID' structure
if 'ID' not in sample_submission.columns:
    raise ValueError("Sample submission file does not contain 'ID' column. Please check the file structure.")

output_path = '/kaggle/working/submission_final_xnn.csv'
submission = sample_submission.copy()
submission['matched_score'] = test_preds_xnn
submission.to_csv(output_path, index=False)
print(f"Submission saved: {output_path}")
print(f"Final Average XNN Cross-Validation MSE: {mean_mse_xnn:.6f}")

# Optional: Save the final XNN model if needed
# model_output_path = '/kaggle/working/final_xnn_model.h5'
# final_xnn_model.save(model_output_path)
# print(f"Final XNN model saved: {model_output_path}")
